# %%
import matplotlib.pyplot as plt
import numpy as np
import numba as nb
import ODEsolver as solve
from run import g, temp, gs, gss
from run import with_spline_ODE, steps_taken
from Emma import sterile_production

# %% [markdown]
# # Spectra

# %% [markdown]
# ### electronx0.00076x1e-10

# %%
data_e = np.load('Neutrino Data/electronx0.00076x1e-10.npz')

plt.figure()
plt.plot(data_e['epsilon'],data_e['epsilon']**2 * data_e['final_distribution'])
plt.xlabel(r"$\epsilon = p_\nu / T_{cm}$")
plt.ylabel(r"$\nu_s$ distribution")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'spectra_e.png'

plt.savefig(image_name, format=image_format, dpi=1200)

# %% [markdown]
# ### muonx0.0011x1e-10

# %%
data_mu = np.load('Neutrino Data/muonx0.0011x1e-10.npz')

plt.figure()
plt.plot(data_mu['epsilon'],data_mu['epsilon']**2 * data_mu['final_distribution'])
plt.xlabel(r"$\epsilon = p_\nu / T_{cm}$")
plt.ylabel(r"$\nu_s$ distribution")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'spectra_mu.png'

plt.savefig(image_name, format=image_format, dpi=1200)

# %% [markdown]
# ### taux0.0013x1e-10

# %%
data_tau = np.load('Neutrino Data/taux0.0013x1e-10.npz')

plt.figure()
plt.plot(data_tau['epsilon'],data_tau['epsilon']**2 * data_tau['final_distribution'])
plt.xlabel(r"$\epsilon = p_\nu / T_{cm}$")
plt.ylabel(r"$\nu_s$ distribution")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'spectra_tau.png'

plt.savefig(image_name, format=image_format, dpi=1200)

# %% [markdown]
# # Lepton evo

# %% [markdown]
# ### electronx0.00076x1e-10

# %%
data_e = np.load('Neutrino Data/electronx0.00076x1e-10.npz')

# %%
plt.figure()
plt.semilogx(data_e['T'], 10**4*data_e['lep_evo'])
plt.xlim(2000,10)
plt.xlabel("T (MeV)")
plt.ylabel(r"Lepton Number $(\times 10^{-4})}$")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'leptonplot_e.png'

plt.savefig(image_name, format=image_format, dpi=1200)

# %% [markdown]
# ### muonx0.0011x1e-10

# %%
data_mu = np.load('Neutrino Data/muonx0.0011x1e-10.npz')
plt.figure()
plt.semilogx(data_mu['T'], 10**4*data_mu['lep_evo'])
plt.xlim(2000,10)
plt.xlabel("T (MeV)")
plt.ylabel(r"Lepton Number $(\times 10^{-4})}$")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'leptonplot_mu.png'

plt.savefig(image_name, format=image_format, dpi=1200)

# %% [markdown]
# ### taux0.0013x1e-10

# %%
data_tau = np.load('Neutrino Data/taux0.0013x1e-10.npz')
plt.figure()
plt.semilogx(data_tau['T'], 10**4*data_tau['lep_evo'])
plt.xlim(2000,10)
plt.xlabel("T (MeV)")
plt.ylabel(r"Lepton Number $(\times 10^{-4})}$")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'leptonplot_tau.png'

plt.savefig(image_name, format=image_format, dpi=1200)

# %% [markdown]
# # Countour plot

# %%
#data_file = np.load('Neutrino Data/electronx0.00076x1e-10.npz')
#L = data_file['lep_evo']
#s = data_file['sstt'] is this mixing angle?
#om = data_file['omega_h2']
#n = data_file['nsh']
#measured_omega_cdm = 0.1188

# %%
#plt.figure()
#plt.contourf(L*1e3, s, om/measured_omega_cdm, levels=[0,0.2, 0.4, 0.6, 0.8, 1])
#plt.colorbar(label=r'$f = \Omega_s h^2 / (\Omega_{DM} h^2)$')

#ns_con = plt.contour(L*1e3, s, n,levels=[40,60,80],colors='white',linewidths=[3,5,3],linestyles=[':','-','--'])
#plt.clabel(ns_con,inline=True,fontsize=14,fmt=r'%1.0f',manual=[(0.003*1e3,1e-9), (0.002*1e3,6e-10),(0.0015*1e3,5e-10)])
#plt.text(3,6e-9,r'$\Omega_s h^2 > \Omega_{DM} h^2$')
#plt.xscale('log')
#plt.yscale('log')
#plt.xlim(1,4.5)
#plt.xlabel(r"Lepton Number $(\times 10^{-3})$")
#plt.ylabel("Mixing Angle")
#image_format = 'png' # e.g .png, .svg, etc.
#image_name = 'DMplot.png'

#plt.savefig(image_name, format=image_format, dpi=1200)

#plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import numba as nb
from Emma3 import sterile_production

# %% [markdown]
# ### All 3 actives $\rightarrow$ sterile

# %%
sterile_production(1000, 0.0071, 10**(-10), 10**(-10), 10**(-10), 7.6e-4, 7.6e-4, 7.6e-4, make_plot=False, folder_name="Neutrino Data")
# Out:
# 0.020560493013478693

# %%
data = np.load('Neutrino Data/three_nux7.6e-04x1.e-10.npz')

# %%
# %%time
plt.figure()
plt.plot(data['epsilon'],data['epsilon']**2 * data['final_distribution'])
plt.plot(data['epsilon'],data['epsilon']**2 * data['sterile_evo'][-1], linestyle = '--')
plt.plot(data['epsilon'],data['epsilon']**2 * data['anti_sterile_evo'][-1], linestyle = ':', linewidth=2)
plt.legend(['$f_{\epsilon} +\overline{f_{\epsilon}}$ ', '$f_{\epsilon}$', '$\overline{f_{\epsilon}}$'])

plt.xlabel(r"$\epsilon = p_\nu / T_{cm}$")
plt.ylabel(r"$\nu_s$ distribution")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'spectra.png'

plt.savefig(image_name, format=image_format, dpi=1200)


plt.figure()
plt.semilogx(data['T'], 10**4*data['lep_evo_e'])
plt.semilogx(data['T'], 10**4*data['lep_evo_mu'], linestyle = '--')
plt.semilogx(data['T'], 10**4*data['lep_evo_tau'], linestyle = ':')
plt.legend([r'$L_{\nu_e}$ Evolution', r'$L_{\nu_{\mu}}$ Evolution', r'$L_{\nu_{\tau}}$ Evolution'])
plt.xlim(2000,10)
plt.xlabel("T (MeV)")
plt.ylabel(r"Lepton Number $(\times 10^{-4})}$")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'leptonplot_e.png'

plt.savefig(image_name, format=image_format, dpi=1200)
# Out:
# CPU times: user 3.46 s, sys: 62.9 ms, total: 3.52 s
# Wall time: 3.52 s

# %% [markdown]
# ### Electron $\rightarrow$ sterile

# %%
sterile_production(4000, 0.0071, 10**(-10), 0, 0, 7.6e-4, 7.6e-4, 7.6e-4, make_plot=False, folder_name="Neutrino Data")
# Out:
# 0.009795613602023242

# %%
data = np.load('Neutrino Data/three_nux7.6e-04x1.e-10.npz')

# %%
# %%time
plt.figure()
plt.plot(data['epsilon'],data['epsilon']**2 * data['final_distribution'])
plt.plot(data['epsilon'],data['epsilon']**2 * data['sterile_evo'][-1], linestyle = '--')
plt.plot(data['epsilon'],data['epsilon']**2 * data['anti_sterile_evo'][-1], linestyle = ':', linewidth=2)
plt.legend(['$f_{\epsilon} +\overline{f_{\epsilon}}$ ', '$f_{\epsilon}$', '$\overline{f_{\epsilon}}$'])

plt.xlabel(r"$\epsilon = p_\nu / T_{cm}$")
plt.ylabel(r"$\nu_s$ distribution")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'spectra.png'

plt.savefig(image_name, format=image_format, dpi=1200)


plt.figure()
plt.semilogx(data['T'], 10**4*data['lep_evo_e'])
plt.semilogx(data['T'], 10**4*data['lep_evo_mu'], linestyle = '--')
plt.semilogx(data['T'], 10**4*data['lep_evo_tau'], linestyle = ':')
plt.legend([r'$L_{\nu_e}$ Evolution', r'$L_{\nu_{\mu}}$ Evolution', r'$L_{\nu_{\tau}}$ Evolution'])
plt.xlim(2000,10)
plt.xlabel("T (MeV)")
plt.ylabel(r"Lepton Number $(\times 10^{-4})}$")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'leptonplot_e.png'

plt.savefig(image_name, format=image_format, dpi=1200)
# Out:
# CPU times: user 3.49 s, sys: 92.9 ms, total: 3.58 s
# Wall time: 3.6 s

# %% [markdown]
# ### Muon $\rightarrow$ sterile

# %%
sterile_production(4000, 0.0071, 0, 10**(-10), 0, 11e-4, 11e-4, 11e-4, make_plot=False, folder_name="Neutrino Data")
# Out:
# 0.013589416715054585

# %%
data = np.load('Neutrino Data/three_nux1.1e-03x0.e+00.npz')

# %%
# %%time
plt.figure()
plt.plot(data['epsilon'],data['epsilon']**2 * data['final_distribution'])
plt.plot(data['epsilon'],data['epsilon']**2 * data['sterile_evo'][-1], linestyle = '--')
plt.plot(data['epsilon'],data['epsilon']**2 * data['anti_sterile_evo'][-1], linestyle = ':', linewidth=2)
plt.legend(['$f_{\epsilon} +\overline{f_{\epsilon}}$ ', '$f_{\epsilon}$', '$\overline{f_{\epsilon}}$'])

plt.xlabel(r"$\epsilon = p_\nu / T_{cm}$")
plt.ylabel(r"$\nu_s$ distribution")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'spectra.png'

plt.savefig(image_name, format=image_format, dpi=1200)


plt.figure()
plt.semilogx(data['T'], 10**4*data['lep_evo_e'])
plt.semilogx(data['T'], 10**4*data['lep_evo_mu'], linestyle = '--')
plt.semilogx(data['T'], 10**4*data['lep_evo_tau'], linestyle = ':')
plt.legend([r'$L_{\nu_e}$ Evolution', r'$L_{\nu_{\mu}}$ Evolution', r'$L_{\nu_{\tau}}$ Evolution'])
plt.xlim(2000,10)
plt.xlabel("T (MeV)")
plt.ylabel(r"Lepton Number $(\times 10^{-4})}$")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'leptonplot_e.png'

plt.savefig(image_name, format=image_format, dpi=1200)
# Out:
# CPU times: user 3.45 s, sys: 94.9 ms, total: 3.54 s
# Wall time: 3.59 s

# %% [markdown]
# ### Tau $\rightarrow$ sterile

# %%
sterile_production(4000, 0.0071, 0, 0, 10**(-10), 13e-4, 13e-4, 13e-4, make_plot=False, folder_name="Neutrino Data")
# Out:
# 0.017406115634492517

# %%
data = np.load('Neutrino Data/three_nux1.3e-03x0.e+00.npz')

# %%
# %%time
plt.figure()
plt.plot(data['epsilon'],data['epsilon']**2 * data['final_distribution'])
plt.plot(data['epsilon'],data['epsilon']**2 * data['sterile_evo'][-1], linestyle = '--')
plt.plot(data['epsilon'],data['epsilon']**2 * data['anti_sterile_evo'][-1], linestyle = ':', linewidth=2)
plt.legend(['$f_{\epsilon} +\overline{f_{\epsilon}}$ ', '$f_{\epsilon}$', '$\overline{f_{\epsilon}}$'])

plt.xlabel(r"$\epsilon = p_\nu / T_{cm}$")
plt.ylabel(r"$\nu_s$ distribution")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'spectra.png'

plt.savefig(image_name, format=image_format, dpi=1200)


plt.figure()
plt.semilogx(data['T'], 10**4*data['lep_evo_e'])
plt.semilogx(data['T'], 10**4*data['lep_evo_mu'], linestyle = '--')
plt.semilogx(data['T'], 10**4*data['lep_evo_tau'], linestyle = ':')
plt.legend([r'$L_{\nu_e}$ Evolution', r'$L_{\nu_{\mu}}$ Evolution', r'$L_{\nu_{\tau}}$ Evolution'])
plt.xlim(2000,10)
plt.xlabel("T (MeV)")
plt.ylabel(r"Lepton Number $(\times 10^{-4})}$")
image_format = 'png' # e.g .png, .svg, etc.
image_name = 'leptonplot_e.png'

plt.savefig(image_name, format=image_format, dpi=1200)
# Out:
# CPU times: user 3.49 s, sys: 104 ms, total: 3.59 s
# Wall time: 3.59 s

# %% [markdown]
# ### trying new folder for organization

# %%
sterile_production(1000, 0.0071, 10**(-10), 0, 0, 7.6e-4, 7.6e-4, 7.6e-4, make_plot=False, folder_name="Electron to Sterile Model")
# Out:
# 0.0095731553726346

# %%
data = np.load('Electron to Sterile Model/three_nux7.6e-04x1.e-10.npz')
data.files
# Out:
# ['T',
#  'final_distribution',
#  'epsilon',
#  'lep_evo_e',
#  'lep_evo_mu',
#  'lep_evo_tau',
#  'a',
#  't',
#  'sterile_evo',
#  'anti_sterile_evo',
#  'mass_s',
#  'mixangv_tot',
#  'Le0',
#  'Lmu0',
#  'Ltau0',
#  'mixangv_e',
#  'mixangv_mu',
#  'mixangv_tau',
#  'omega_h2']

# %%
sin2 = data['mixangv_e']
print(sin2)
# Out:
# 1e-10

# %%
le= data['lep_evo_e']
lmu= data['lep_evo_mu']
ltau= data['lep_evo_tau']
eps = data['epsilon']

# %%
print(data['T'])
# Out:
# [1960.5869    1885.8932    1814.5612    1746.4398    1681.3843
#  1619.2567    1559.9254    1503.2644    1449.1536    1397.4782
#  1348.1285    1301.        1255.9926    1213.0108    1171.9636
#  1132.7638    1095.3282    1059.5776    1025.436      992.83097
#   961.69345    931.95734    903.55959    876.43994    850.54087
#   825.80746    802.18723    779.63009    758.08819    737.51583
#   717.86938    699.10717    681.1894     664.07805    647.73685
#   632.13112    617.22777    602.99517    589.40315    576.42287
#   564.0268     552.18864    540.88329    530.08677    519.77616
#   509.92961    500.52623    491.54607    482.97009    474.78008
#   466.95869    459.48932    452.35612    445.54398    439.03843
#   432.82567    426.89254    421.22644    415.81536    410.64782
#   405.71285    401.         396.49926    392.20108    388.09636
#   384.17638    380.43282    376.85776    373.4436     370.1831
#   367.06934    364.09573    361.25596    358.54399    355.95409
#   353.48075    351.11872    348.86301    346.70882    344.65158
#   342.68694    340.81072    339.01894    337.30781    335.67369
#   334.11311    332.62278    331.19952    329.84032    328.54229
#   327.30268    326.11886    324.98833    323.90868    322.87762
#   321.89296    320.95262    320.05461    319.19701    318.37801
#   317.59587    316.84893    316.13561    315.4544     314.80384
#   314.18257    313.58925    313.02264    312.48154    311.96478
#   311.47129    311.         310.54993    310.12011    309.70964
#   309.31764    308.94328    308.58578    308.24436    307.91831
#   307.60693    307.30957    307.0256     306.7544     306.49541
#   306.24807    306.01187    305.7863     305.57088    305.36516
#   305.16869    304.98107    304.80189    304.63078    304.46737
#   304.31131    304.16228    304.01995    303.88403    303.75423
#   303.63027    303.51189    303.39883    303.29087    303.18776
#   303.0893     302.99526    302.90546    302.8197     302.7378
#   302.65959    302.58489    302.51356    302.44544    302.38038
#   302.31826    302.25893    302.20226    302.14815    302.09648
#   302.04713    302.         300.         290.         280.
#   270.         260.         250.         240.         230.
#   220.         210.         200.         190.         180.
#   170.         160.         150.         147.94444    145.88889
#   143.83333    141.77778    139.72222    137.66667    135.61111
#   133.55556    131.5        129.44444    127.38889    125.33333
#   123.27778    121.22222    119.16667    117.11111    115.05556
#   113.         110.94444    108.88889    106.83333    104.77778
#   102.72222    100.66667     98.611111    96.555556    94.5
#    92.444444    90.388889    88.333333    86.277778    84.222222
#    82.166667    80.111111    78.055556    76.          73.944444
#    71.888889    69.833333    67.777778    65.722222    63.666667
#    61.611111    59.555556    57.5         55.444444    53.388889
#    51.333333    49.277778    47.222222    45.166667    43.111111
#    41.055556    39.          36.944444    34.888889    32.833333
#    30.777778    28.722222    26.666667    24.611111    22.555556
#    20.5         18.444444    16.388889    14.333333    12.277778
#    10.222222     8.1666667]

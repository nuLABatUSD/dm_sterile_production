# %%
import matplotlib.pyplot as plt
import numpy as np
import numba as nb
from Emma3 import sterile_production

# %% [markdown]
# sterile_production(1000, 0.0071, 10**(-10), 10**(-10), 10**(-10), 7.6e-4, 7.6e-4, 7.6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "three_nu")

# %%
sterile_production(1000, 0.0071, 10**(-10), 10**(-10), 10**(-10), 6e-4, 6e-4, 6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m10")
sterile_production(1000, 0.0071, 10**(-10), 10**(-10), 10**(-10), 7.6e-4, 7.6e-4, 7.6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m10")
sterile_production(1000, 0.0071, 10**(-10), 10**(-10), 10**(-10), 11e-4, 11e-4, 11e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m10")
sterile_production(1000, 0.0071, 10**(-10), 10**(-10), 10**(-10), 13e-4, 13e-4, 13e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m10")
sterile_production(1000, 0.0071, 10**(-10), 10**(-10), 10**(-10), 15e-4, 15e-4, 15e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m10")

sterile_production(1000, 0.0071, 10**(-9), 10**(-9), 10**(-9), 6e-4, 6e-4, 6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m9")
sterile_production(1000, 0.0071, 10**(-9), 10**(-9), 10**(-9), 7.6e-4, 7.6e-4, 7.6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m9")
sterile_production(1000, 0.0071, 10**(-9), 10**(-9), 10**(-9), 11e-4, 11e-4, 11e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m9")
sterile_production(1000, 0.0071, 10**(-9), 10**(-9), 10**(-9), 13e-4, 13e-4, 13e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m9")
sterile_production(1000, 0.0071, 10**(-9), 10**(-9), 10**(-9), 15e-4, 15e-4, 15e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m9")

sterile_production(1000, 0.0071, 10**(-8), 10**(-8), 10**(-8), 6e-4, 6e-4, 6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m8")
sterile_production(1000, 0.0071, 10**(-8), 10**(-8), 10**(-8), 7.6e-4, 7.6e-4, 7.6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m8")
sterile_production(1000, 0.0071, 10**(-8), 10**(-8), 10**(-8), 11e-4, 11e-4, 11e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m8")
sterile_production(1000, 0.0071, 10**(-8), 10**(-8), 10**(-8), 13e-4, 13e-4, 13e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m8")
sterile_production(1000, 0.0071, 10**(-8), 10**(-8), 10**(-8), 15e-4, 15e-4, 15e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m8")

sterile_production(1000, 0.0071, 10**(-7), 10**(-7), 10**(-7), 6e-4, 6e-4, 6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m7")
sterile_production(1000, 0.0071, 10**(-7), 10**(-7), 10**(-7), 7.6e-4, 7.6e-4, 7.6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m7")
sterile_production(1000, 0.0071, 10**(-7), 10**(-7), 10**(-7), 11e-4, 11e-4, 11e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m7")
sterile_production(1000, 0.0071, 10**(-7), 10**(-7), 10**(-7), 13e-4, 13e-4, 13e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m7")
sterile_production(1000, 0.0071, 10**(-7), 10**(-7), 10**(-7), 15e-4, 15e-4, 15e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m7")

sterile_production(1000, 0.0071, 10**(-6), 10**(-6), 10**(-6), 6e-4, 6e-4, 6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m6")
sterile_production(1000, 0.0071, 10**(-6), 10**(-6), 10**(-6), 7.6e-4, 7.6e-4, 7.6e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m6")
sterile_production(1000, 0.0071, 10**(-6), 10**(-6), 10**(-6), 11e-4, 11e-4, 11e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m6")
sterile_production(1000, 0.0071, 10**(-6), 10**(-6), 10**(-6), 13e-4, 13e-4, 13e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m6")
sterile_production(1000, 0.0071, 10**(-6), 10**(-6), 10**(-6), 15e-4, 15e-4, 15e-4, make_plot=False, folder_name="3to1 model", file_prefix = "m6")
# Out:
# 36.269079591539445

# %%
data = np.load('3to1 model/three_nux1.3e-03x3.e-10.npz')

# %%
print (data['epsilon'])
# Out:
# [1.00000000e-02 3.00100100e-02 5.00200200e-02 7.00300300e-02
#  9.00400400e-02 1.10050050e-01 1.30060060e-01 1.50070070e-01
#  1.70080080e-01 1.90090090e-01 2.10100100e-01 2.30110110e-01
#  2.50120120e-01 2.70130130e-01 2.90140140e-01 3.10150150e-01
#  3.30160160e-01 3.50170170e-01 3.70180180e-01 3.90190190e-01
#  4.10200200e-01 4.30210210e-01 4.50220220e-01 4.70230230e-01
#  4.90240240e-01 5.10250250e-01 5.30260260e-01 5.50270270e-01
#  5.70280280e-01 5.90290290e-01 6.10300300e-01 6.30310310e-01
#  6.50320320e-01 6.70330330e-01 6.90340340e-01 7.10350350e-01
#  7.30360360e-01 7.50370370e-01 7.70380380e-01 7.90390390e-01
#  8.10400400e-01 8.30410410e-01 8.50420420e-01 8.70430430e-01
#  8.90440440e-01 9.10450450e-01 9.30460460e-01 9.50470470e-01
#  9.70480480e-01 9.90490490e-01 1.01050050e+00 1.03051051e+00
#  1.05052052e+00 1.07053053e+00 1.09054054e+00 1.11055055e+00
#  1.13056056e+00 1.15057057e+00 1.17058058e+00 1.19059059e+00
# ...
